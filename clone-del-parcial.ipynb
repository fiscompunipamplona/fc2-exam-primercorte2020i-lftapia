# %%
from google.colab import drive
from os.path import join

# %%
ROOT = '/content/drive'
PROJ = 'My Drive/primerClone'

GIT_USERNAME = "lftapia"
GIT_TOKEN = "e113daf242f6cd8168b5bcba866077ccd0086814"
GIT_REPOSITORY = "fiscompunipamplona/fc2-exam-primercorte2020i-lftapia.git"
GIT_PATH = "https://e113daf242f6cd8168b5bcba866077ccd0086814@github.com/fiscompunipamplona/fc2-exam-primercorte2020i-lftapia.git"
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/primerClone’: File exists

# %%
PROJECT_PATH = join(ROOT, PROJ)

# !git clone "{GIT_PATH}"
# !rsync -aP fc2-exam-primercorte2020i-lftapia "{PROJECT_PATH}"
# Out:
# Cloning into 'fc2-exam-primercorte2020i-lftapia'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.
# sending incremental file list
# fc2-exam-primercorte2020i-lftapia/
# fc2-exam-primercorte2020i-lftapia/Casos1_13abr2020.csv
#         241,182 100%   49.69MB/s    0:00:00 (xfr#1, to-chk=51/53)
# fc2-exam-primercorte2020i-lftapia/fc2_exam_primerCorte2020i.ipynb
#           4,317 100%    1.03MB/s    0:00:00 (xfr#2, to-chk=50/53)
# fc2-exam-primercorte2020i-lftapia/planets_2020.04.13_08.06.56.tab
#          19,344 100%    3.69MB/s    0:00:00 (xfr#3, to-chk=49/53)
# fc2-exam-primercorte2020i-lftapia/.git/
# fc2-exam-primercorte2020i-lftapia/.git/HEAD
#              23 100%    0.00kB/s    0:00:00 (xfr#4, to-chk=47/53)
# fc2-exam-primercorte2020i-lftapia/.git/config
# ...

# %%
# %cd "{PROJECT_PATH}"/fc2-exam-primercorte2020i-lftapia/
# !ls
# !git config --global user.email "luislomaximo30@gmail.com"
# !git config --global user.name "lftapia"

# !git remote rm origin

# !git config --global github.user "{GIT_USERNAME}"
# !git config --global github.token "{GIT_TOKEN}"

# !git add *
# !git commit -m "Solución del Parcial primer corte"

# !git remote add origin https://"{GIT_TOKEN}"@github.com/"{GIT_REPOSITORY}"

# !git push -u origin master
# Out:
# /content/drive/My Drive/primerClone/fc2-exam-primercorte2020i-lftapia
# Casos1_13abr2020.csv		 Parcial_1.ipynb
# Casos1_13abr2020.gsheet		 planets_2020.04.13_08.06.56.tab
# clone-del-parcial.ipynb		 planets_2020.04.13_08.06.56.tab.gsheet
# fc2_exam_primerCorte2020i.ipynb  __pycache__
# momento.py
# error: open("Casos1_13abr2020.gsheet"): Operation not supported
# error: unable to index file Casos1_13abr2020.gsheet
# fatal: adding files failed
# On branch master
# Untracked files:
# 	Casos1_13abr2020.gsheet
# 	Parcial_1.ipynb
# 	__pycache__/
# 	clone-del-parcial.ipynb
# 	momento.py
# 	planets_2020.04.13_08.06.56.tab.gsheet
#
# nothing added to commit but untracked files present
# Branch 'master' set up to track remote branch 'master' from 'origin'.
# Everything up-to-date
